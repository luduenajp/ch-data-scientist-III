# %%
import nltk
import spacy
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud ## --> visualizar nube de palabras (frecuencia)
from collections import Counter ## --> contador
from sklearn.model_selection import train_test_split ## --> train test split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer ## --> feature_extraction: retenedor de caracteristicas - vectorizar y contar - ponderación por cantidad de apariciones
from sklearn.naive_bayes import MultinomialNB ## --> modelo - ponderar como el tfidf - clasificación (sentimental analysis)
from sklearn.pipeline import Pipeline ## --> ejectuar tareas en secuencia de manera repetida
from sklearn.metrics import accuracy_score, classification_report ## --> metricas

# Descargar recursos necesarios de nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
# Out:
# Running cells with 'Python 3.12.5' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/local/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Cargar modelo de spaCy en inglés
nlp = spacy.load("en_core_web_sm")

# %%
# Cargar dataset
df = pd.read_csv('https://raw.githubusercontent.com/nacho1907/Bases/refs/heads/main/fake_or_real_news.csv')
df.shape
# Out:
# (6335, 4)

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
df = df.rename(columns={"text": "texto", "label": "sentimiento"})
df.head()
# unnamed --> id, se puede descartar
# title -->
# texto -->
# sentimiento --> real o fake
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                texto sentimiento
# 0  Daniel Greenfield, a Shillman Journalism Fello...        FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...        FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...        REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...        FAKE
# 4  It's primary day in New York and front-runners...        REAL

# %%
df.set_index('Unnamed: 0')
# Out:
#                                                         title  \
# Unnamed: 0
# 8476                             You Can Smell Hillary’s Fear
# 10294       Watch The Exact Moment Paul Ryan Committed Pol...
# 3608              Kerry to go to Paris in gesture of sympathy
# 10142       Bernie supporters on Twitter erupt in anger ag...
# 875          The Battle of New York: Why This Primary Matters
# ...                                                       ...
# 4490        State Department says it can't find emails fro...
# 8062        The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 8622        Anti-Trump Protesters Are Tools of the Oligarc...
# 4021        In Ethiopia, Obama seeks progress on peace, se...
# 4330        Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                         texto sentimiento
# Unnamed: 0
# 8476        Daniel Greenfield, a Shillman Journalism Fello...        FAKE
# ...

# %% [markdown]
# DS para la detección de fake-news

# %%
# Contar cuantas noticias reales y fakes hay en el dataset
# Està balanceado? Còmo lo arreglarìas sino?

# %%
cantidades_sentimiento = df['sentimiento'].value_counts()
print(cantidades_sentimiento)
# Out:
# sentimiento
# REAL    3171
# FAKE    3164
# Name: count, dtype: int64

# %%
# informado en porcentajes
porcentajes_sentimiento = (cantidades_sentimiento / cantidades_sentimiento.sum()) * 100
porcentajes_sentimiento
# Out:
# sentimiento
# REAL    50.055249
# FAKE    49.944751
# Name: count, dtype: float64

# %% [markdown]
# Al ser los porcentajes muy parecidos podemos decir que el dataset SI está balanceado.

# %%
#Cómo lo arreglarías sino?

# %% [markdown]
# Si el dataset estuviese desbalanceado, podría servir hacer un Submuestreo (undersampling), donde las cantidades de noticias FAKE y REAL sean iguales

# %%
# Dimensiona el dataset
# En término de variable que diferencias encuentras con los que usabas en Machine Learning?

# Información detallada del dataset
print("Información del dataset:")
print(df.info())
# Out:
# Información del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6335 entries, 0 to 6334
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   6335 non-null   int64
#  1   title        6335 non-null   object
#  2   texto        6335 non-null   object
#  3   sentimiento  6335 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 198.1+ KB
# None

# %% [markdown]
# En éste tipo de datasets la principal diferencia que veo son las cantidades de columnas que son necesarias. Además el valor de estas columnas en su mayoría son textos bastante largos y complejos, no hay tipificaciónes

# %%
# Corta a un nùmero reducido de noticias para facilitar el procesamiento
# Las clases quedaron balanceadas?
df_reducido = df.head(750)

# Mostrar el tamaño del dataset reducido
print("Nuevo tamaño del dataset reducido:", df_reducido.shape)
cantidades_reducido = df_reducido['sentimiento'].value_counts()
print(cantidades_reducido)

# informado en porcentajes
print("expresado en porcentajes: ", ((cantidades_reducido / cantidades_reducido.sum()) * 100))
# Out:
# Nuevo tamaño del dataset reducido: (750, 4)
# sentimiento
# REAL    382
# FAKE    368
# Name: count, dtype: int64
# expresado en porcentajes:  sentimiento
# REAL    50.933333
# FAKE    49.066667
# Name: count, dtype: float64

# %% [markdown]
# El DS sigue balanceado luego de seleccionar las primeras 750 noticias

# %%
# Ajustar etiquetas de sentimiento (0 = fake, 1 = real)

# %%
df_reducido['sentimiento'] = df_reducido['sentimiento'].map({'FAKE': 0, 'REAL': 1})
df_reducido.head()
# Out:
# <ipython-input-18-828884694474>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reducido['sentimiento'] = df_reducido['sentimiento'].map({'FAKE': 0, 'REAL': 1})
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                texto  sentimiento
# 0  Daniel Greenfield, a Shillman Journalism Fello...            0
# ...

# %%
def preprocesar_texto(texto):
    """Tokeniza, elimina stopwords, lematiza y elimina caracteres especiales."""
    doc = nlp(str(texto).lower())  # Convertir a minúsculas y procesar con spaCy
    tokens = [token.lemma_ for token in doc if token.is_alpha and token.text not in stopwords.words('english')]
    return " ".join(tokens)

# %%
# Aplicar la función de preprocesamiento al texto
df_reducido['texto_preprocesado'] = df_reducido['texto'].apply(preprocesar_texto)
df_reducido.head()
# Out:
# <ipython-input-21-8b760537daf2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reducido['texto_preprocesado'] = df_reducido['texto'].apply(preprocesar_texto)
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                texto  sentimiento  \
# 0  Daniel Greenfield, a Shillman Journalism Fello...            0
# ...

# %%
# Visualizar nube de palabras completando la secuencia de creaciòn
text_combined = " ".join(df_reducido['texto_preprocesado'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_combined)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Nube de palabras")
plt.show()

# %%
df_reducido['texto_preprocesado']
# Out:
# 0      daniel greenfield shillman journalism fellow f...
# 1      google pinterest digg linkedin reddit stumbleu...
# 2      secretary state john kerry say monday stop par...
# 3      kaydee king november lesson tonight dem loss t...
# 4      primary day new york front runner hillary clin...
#                              ...
# 745    topic hillary clinton donald trump presidentia...
# 746    beirut ap islamic state militant accept pledge...
# 747    bni store nov wife muslim jihadist kill wound ...
# 748    twitter batchelorshow farming invent many time...
# 749    israeli prime minister benjamin netanyahu warn...
# Name: texto_preprocesado, Length: 750, dtype: object

# %%
# Análisis de n-grams, adicionar bigramas, trigramas y cuatrigramas. Plotearlos.
def get_top_ngrams(corpus, n, top_k=10):
    vectorizer = CountVectorizer(ngram_range=(n, n))
    X = vectorizer.fit_transform(corpus)
    ngram_counts = X.sum(axis=0).A1
    ngram_features = vectorizer.get_feature_names_out()
    ngram_freq = list(zip(ngram_features, ngram_counts))
    ngram_freq = sorted(ngram_freq, key=lambda x: x[1], reverse=True)[:top_k]
    return pd.DataFrame(ngram_freq, columns=['N-gram', 'Frecuencia'])

def plot_ngrams(ngram_df, title):
    plt.figure(figsize=(10, 5))
    sns.barplot(x='Frecuencia', y='N-gram', data=ngram_df, palette='viridis')
    plt.title(title)
    plt.xlabel("Frecuencia")
    plt.ylabel("N-gram")
    plt.show()

unigrams = get_top_ngrams(df_reducido['texto_preprocesado'], 1)
bigrams = get_top_ngrams(df_reducido['texto_preprocesado'], 2)
trigrams = get_top_ngrams(df_reducido['texto_preprocesado'], 3)
cuatrigrams = get_top_ngrams(df_reducido['texto_preprocesado'], 4)


print("Unigramas más comunes:")
print(unigrams)
plot_ngrams(unigrams, "Unigramas más comunes")

print("\nBigramas más comunes:")
print(bigrams)
plot_ngrams(bigrams, "Bigramas más comunes")

print("\nTrigramas más comunes:")
print(trigrams)
plot_ngrams(trigrams, "Trigramas más comunes")

print("\nCuatrigramas más comunes:")
print(cuatrigrams)
plot_ngrams(cuatrigrams, "Cuatrigramas más comunes")
# Out:
# Unigramas más comunes:
#     N-gram  Frecuencia
# 0      say        3773
# 1    trump        2891
# 2  clinton        2465
# 3    would        1631
# 4    state        1604
# 5      one        1431
# 6   people        1396
# 7     make        1338
# 8       go        1325
# 9     year        1194
# <ipython-input-32-7ab58482c08c>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Frecuencia', y='N-gram', data=ngram_df, palette='viridis')
# <ipython-input-32-7ab58482c08c>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Frecuencia', y='N-gram', data=ngram_df, palette='viridis')
# Bigramas más comunes:
#              N-gram  Frecuencia
# 0   hillary clinton         554
# ...

# %%
# Separar datos en entrenamiento y prueba
x = df_reducido['texto_preprocesado']
y = df_reducido['sentimiento']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print("Tamaño del conjunto de entrenamiento:", X_train.size)
print("Tamaño del conjunto de prueba:", X_test.size)
# Out:
# Tamaño del conjunto de entrenamiento: 600
# Tamaño del conjunto de prueba: 150

# %%
# Pipeline de vectorización y modelo
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('clf', MultinomialNB())
])

# %%
# Entrenar modelo
pipeline.fit(X_train, y_train)

# Predicciones
y_pred = pipeline.predict(X_test)

# %%
# Evaluación
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7733333333333333
#               precision    recall  f1-score   support
#
#            0       0.95      0.53      0.68        68
#            1       0.71      0.98      0.82        82
#
#     accuracy                           0.77       150
#    macro avg       0.83      0.75      0.75       150
# weighted avg       0.82      0.77      0.76       150

# %%
##DataFlair - Initialize a TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_df =0.9)
## DataFlair - fit and transform train set, transform test set
tfidf_train = tfidf_vectorizer.fit_transform(X_train)
tfidf_test = tfidf_vectorizer.transform(X_test)

# %%
from sklearn.linear_model import PassiveAggressiveClassifier
pac=PassiveAggressiveClassifier(max_iter=50)
pac.fit(tfidf_train,y_train)
# Out:
# PassiveAggressiveClassifier(max_iter=50)

# %%
y_pred2=pac.predict(tfidf_test)

# %%
# Evaluación
print("Accuracy:", accuracy_score(y_test, y_pred2))
print(classification_report(y_test, y_pred2))
# Out:
# Accuracy: 0.92
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91        68
#            1       0.94      0.91      0.93        82
#
#     accuracy                           0.92       150
#    macro avg       0.92      0.92      0.92       150
# weighted avg       0.92      0.92      0.92       150

# %% [markdown]
# Con los resultados obtenidos podemos deducir que es mejor predecir absolutismos, que es lo que nos brinda el modelo PassiveAggressiveClassifier de sklearn
